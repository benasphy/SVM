# %% [markdown]
# <a href="https://colab.research.google.com/github/benasphy/SVM/blob/main/SVM_Breast_Cancer_prediction_with_Sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('/content/data.csv')
# Drop the 'Unnamed: 32' column as it appears to be empty and causing display issues.
df = df.drop(columns=['Unnamed: 32'])
display(df.head())
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
encoder = LabelEncoder()
df['diagnosis'] = encoder.fit_transform(df['diagnosis'])
display(df.head())
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
X = df.drop('diagnosis', axis=1)
y = df['diagnosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train_Scaled = scaler.fit_transform(X_train)
X_test_Scaled = scaler.transform(X_test)

# %%
model = SVC(kernel='rbf', C = 1.0, gamma='scale', probability=True)
model.fit(X_train_Scaled, y_train)
# Out:
# SVC(probability=True)

# %%
y_pred = model.predict(X_test_Scaled)

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.9766081871345029

# %%
new_data_for_prediction = pd.DataFrame({
    'id': [999999, 888888],
    'radius_mean': [15.0, 12.5],
    'texture_mean': [20.0, 15.0],
    'perimeter_mean': [95.0, 80.0],
    'area_mean': [700.0, 500.0],
    'smoothness_mean': [0.1, 0.08],
    'compactness_mean': [0.15, 0.09],
    'concavity_mean': [0.1, 0.05],
    'concave points_mean': [0.05, 0.03],
    'symmetry_mean': [0.18, 0.16],
    'fractal_dimension_mean': [0.06, 0.055],
    'radius_se': [0.4, 0.2],
    'texture_se': [1.0, 0.8],
    'perimeter_se': [3.0, 1.5],
    'area_se': [40.0, 20.0],
    'smoothness_se': [0.005, 0.003],
    'compactness_se': [0.03, 0.015],
    'concavity_se': [0.03, 0.01],
    'concave points_se': [0.01, 0.005],
    'symmetry_se': [0.02, 0.012],
    'fractal_dimension_se': [0.003, 0.002],
    'radius_worst': [18.0, 14.0],
    'texture_worst': [28.0, 20.0],
    'perimeter_worst': [120.0, 90.0],
    'area_worst': [1000.0, 650.0],
    'smoothness_worst': [0.15, 0.1],
    'compactness_worst': [0.4, 0.2],
    'concavity_worst': [0.4, 0.2],
    'concave points_worst': [0.15, 0.08],
    'symmetry_worst': [0.3, 0.25],
    'fractal_dimension_worst': [0.1, 0.07]
})
display(new_data_for_prediction.head())
# Out:
#        id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  999999         15.0          20.0            95.0      700.0
# 1  888888         12.5          15.0            80.0      500.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0             0.10              0.15            0.10                 0.05
# 1             0.08              0.09            0.05                 0.03
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0           0.18  ...          18.0           28.0            120.0
# 1           0.16  ...          14.0           20.0             90.0
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      1000.0              0.15                0.4              0.4
# 1       650.0              0.10                0.2              0.2
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.15            0.30                     0.10
# ...

# %%
new_data_for_prediction_scaled = scaler.fit_transform(new_data_for_prediction)

# %%
new_predictions = model.predict(new_data_for_prediction_scaled)
for prediction in new_predictions:
  if prediction == 1:
    print("Malignant")
  else:
    print("Benign")
# Out:
# Malignant
# Benign
